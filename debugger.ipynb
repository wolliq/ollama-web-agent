# %%
import requests
import ollama

from ollama import EmbedResponse
from loguru import logger


model = "llama2-7b"

texts = [
    "ARM Vs X86 | Difference | Comparison ECSTUFF4U for Electronics Engineer ECSTUFF4U | ONLINE ELECTRONICS, ELECTRICAL ENGINEERING KNOWLEDGE | RESEARCH | INFORMATION | Page Power Electronics Wireless Communication Integrated Circuits Optical Communication Digital Signal Processing VLSI Networking Microcontroller Electronics Devices Electrical Machine Differences Advantages and Disadvantages Functions Full Forms Write for Us Students Corner ARM Vs X86 | Difference | Comparison The main differences between ARM and X86 are in terms of cost, power consumption, and performance. ARM processors are more power efficient than X86, and therefore are preferable in battery-powered devices. What is ARM? ARM stands for advanced RISC machine, It is an instruction set architecture(ISA) developed by ARM Holding which is designed for the reduction of complexity, power consumption, and cost in computer processors and other components. This architecture is widely used in mobile phones, personal digital assistants, and handhelds. Learn More about x64 Vs x86 What is x86? x86 is a CISC (Complex instruction set computing) instruction set architecture developed by Intel Corporation and introduced in 1978. It is the most popular ISA used in PCs. It has been extensively used in desktop, laptop, and server computers since the 1980s. ARM Vs X86 | Difference between ARM and X86 ARM uses reduced instruction set computing architecture(RISC), but X86 uses complex instruction set computing architecture(CISC). While X86 processes complex instructions one at a time over a longer period of time than ARM, ARM processes a single instruction every cycle. ARM optimization of performance with a software-focused approach, whereas X86 hardware approach to optimize performance. X86 uses greater memory and fewer registers, but ARM uses more memory and more registers. ARM pipelining of instruction is unique, on the other hand, X86 is less pipelined. ARM is faster execution of instruction reduces time, X86 is time to execute is more. ARM is complex addressing managed by software, and X86 is inherently designed to handle complex addresses. ARM is complier and plays a key role in managing operations, X86 is the microprogram that does the trick. ARM managing code expansion is difficult, in X86 code expansion is managed easily. ARM is multiple instructions generated from a complex one and executed individually, X86 architecture is capable of managing complex statement execution at a time. Decoding of instruction is handled easily in ARM, In X86, Decoding is handled in a complex way. ARM uses available memory for calculation, and X86 needs supplemented memory for calculations. ARM deployed in mobile devices where size, and power consumption speed matter, whereas X86 deployed in servers, desktops, and laptops where high performance and stability matter. Thank you for reading this article, If you have any queries regarding this article on ARM Vs X86 then feel free to comment and give suggestions in the comment section below. Explore more information: Difference between microprocessor and microcontroller 8 bit Vs 16-bit Microcontroller FPGA Vs Microcontroller AVR Vs ARM AVR Vs PIC Features of ARM Processor Features of 8051 Microcontroller Application of PLC Email This BlogThis! Share to X Share to Facebook Share to Pinterest Newer Post Older Post Home Pages About Contact Privacy Disclaimers Terms and Condition Blog Archive Blog Archive October (1) March (1) February (3) January (2) August (1) July (3) June (5) May (1) April (5) March (4) February (13) January (10) December (15) November (13) October (14) September (14) August (10) July (11) June (12) May (12) April (18) March (48) February (15) January (15) December (21) November (17) October (8) September (4) August (5) July (5) June (1) April (5) March (31) February (28) January (31) December (31) November (30) October (31) September (30) August (31) July (31) June (30) May (37) April (30) March (31) February (28) January (31) December (31) November (20) October (17) September (30) August (31) July (35) June (30) May (31) April (60) March (49) February (29) January (31) December (21) November (17) October (10) September (5) August (29) July (31) June (17) May (30) April (30) March (31) February (17) January (3) December (3) November (10) October (10) September (43) August (31) July (32) June (5) May (95) April (42) March (92) February (73) January (29) December (28) November (62) October (9) Labels advance OFS Advantages ammeter Audio video system basic electronics Bluetooth books CDMA CDMA 2000 Cellular concepts Channel access method chopper circuit breaker Clipper clamper circuit Converter and Inverter Cyclo-converter Definition DFT Difference DSP DT signals and system electric drive electric wiring Electrical Machine Electronics device FDMA Filter design techniques Floppy Disk Full Form Functions GPRS GSM Guest post Hard disk floppy disk IC Kits Laser diode latest wireless technology LED MCB MCQ Question Answer Microcontroller multimeter Networking OFC OFDM Optical amplifier Optical communication Optical source Photodiode Power Electronics Power electronics applications Power semicoductor diode Power transistor Project Question-Answer Refresh rate RTD SDMA Spread spectrum method Students"
]

OLLAMA_HOST = "http://localhost:11434"
url = f"{OLLAMA_HOST}/api/embeddings"

for t in texts:
    embeddings: EmbedResponse = ollama.embed(
        model='nomic-embed-text',
        input='Llamas are members of the camelid family',
    )
    
    logger.debug(embeddings.embeddings)
    
# resp = requests.post(
#     url, json={"model": model, "input": texts}, timeout=120
# )
# resp.raise_for_status()

# print(resp.json())
# Out:
# 2025-11-07 14:28:50.023 | DEBUG    | __main__:<module>:23 - [[0.014536031, 0.014443452, -0.15874997, -0.056535657, 0.013795241, 0.00045104788, -0.08254486, -0.07521383, -0.04013904, -0.005840026, -0.007070718, 0.047681723, 0.06997294, 0.017274851, 0.039210733, -0.020920668, -0.06032339, -0.017445924, 0.041513465, 0.024653696, -0.06401477, 0.041886885, 0.009406567, -0.02421237, 0.06156783, -0.0098030325, -0.024692742, 0.048724253, 0.005086468, -0.0204259, 0.0874297, 0.0100197615, 0.017623276, -0.025293263, 0.005653473, 0.029439291, 0.09163349, 0.032958638, 0.0790623, 0.015896752, 0.062164523, -0.008954088, 0.031672414, 0.016500734, 0.04917534, -0.040213063, 0.0458487, 0.04488526, 0.092673376, -0.013454861, 0.037469223, -0.034229074, -0.011449082, 0.013899965, 0.027330833, -0.0002377891, 0.009163089, 0.009379682, -0.011087061, -0.051596012, 0.057421327, -0.018616261, -0.012755159, 0.074725054, 0.011863401, -0.046663202, -0.04515676, 0.0010293807, -0.01963995, -0.0014479243, 0.033547297
# ...
